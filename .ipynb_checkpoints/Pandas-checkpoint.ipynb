# %% [markdown]
# ## PANDAS CHEAT SHEET

# %% [markdown]
# pandas is a Python package providing fast, flexible, and expressive data structures designed to work with relational or labeled data both. It is a fundamental high-level building block for doing practical, real world data analysis in Python.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Data  Structure

# %% [markdown]
# ## Series

# %% [markdown]
# A Series is a single vector of data (like a NumPy array) with an index that labels each element in the vector.

# %% [markdown]
#  s = pd.Series(data, index=index)
#  data can be many different things:
#  a Python dict
#  an ndarray
#  a scalar value (like 5)

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
print(s)
# Out:
# a    1.035711
# b   -0.465305
# c    0.650014
# d    1.604866
# e   -0.955521
# dtype: float64

# %%
c=pd.Series([630,25,26,255])
print(c)
# Out:
# 0    630
# 1     25
# 2     26
# 3    255
# dtype: int64

# %% [markdown]
# If an index is not specified, a default sequence of integers is assigned as the index. A NumPy array comprises the values of the Series, while the index is a pandas Index object.

# %%
c.values
# Out:
# array([630,  25,  26, 255])

# %%
c.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#assigning meanngful indexes
points=pd.Series([630,25,26,255],
    index=['India','Bangladesh','Pakistan','China'])
print(points)
# Out:
# India         630
# Bangladesh     25
# Pakistan       26
# China         255
# dtype: int64

# %%
#refering values using labels
points['India']
# Out:
# 630

# %%
points[[p.endswith("a") for p in points.index]]
# Out:
# India    630
# China    255
# dtype: int64

# %%
[p.endswith("a") for p in points.index]
# Out:
# [True, False, False, True]

# %%
#we can still use default indexing style
points[0]
# Out:
# 630

# %%
#giving the values and index itelf a label
points.name="WorldCup"
points.index.name="Previous Points"
points
# Out:
# Previous Points
# India         630
# Bangladesh     25
# Pakistan       26
# China         255
# Name: WorldCup, dtype: int64

# %%
#applying nupy math functions without losing datastructure
np.log(points)
# Out:
# Previous Points
# India         6.445720
# Bangladesh    3.218876
# Pakistan      3.258097
# China         5.541264
# Name: WorldCup, dtype: float64

# %%
#filtering values
points[points>100]
# A series is an ordered key-value store
# Out:
# Previous Points
# India    630
# China    255
# Name: WorldCup, dtype: int64

# %% [markdown]
# points < 1000 returns a Series of True/False values, which we then pass to our Series points, returning the corresponding True items.

# %%
#creating a serie from a dicionary
points_dic={"India":345,"Bangladesh":456,"Pakistan":789,"China":90}
points=pd.Series(points_dic)
points
#will be created in key sorted order
# Out:
# Bangladesh    456
# China          90
# India         345
# Pakistan      789
# dtype: int64

# %% [markdown]
# If we pass a custom index to Series, it will select the corresponding values from the dict, and treat indices without corrsponding values as missing. Pandas uses the NaN (not a number) type for missing values.

# %%
points2=pd.Series(points_dic,index=["Spain","India","China","France"])
points2
# Out:
# Spain       NaN
# India     345.0
# China      90.0
# France      NaN
# dtype: float64

# %%
points2.isnull()
# Out:
# Spain      True
# India     False
# China     False
# France     True
# dtype: bool

# %%
print(points)
print(points2)
print(points+points2)
#u can drop missing values by using dropna
(points+points2).dropna()
# Out:
# Bangladesh    456
# China          90
# India         345
# Pakistan      789
# dtype: int64
# Spain       NaN
# India     345.0
# China      90.0
# France      NaN
# dtype: float64
# Bangladesh      NaN
# China         180.0
# France          NaN
# India         690.0
# Pakistan        NaN
# Spain           NaN
# dtype: float64
# China    180.0
# India    690.0
# dtype: float64

# %% [markdown]
# You can add two Series together, which returns a union of the two Series with the addition occurring on the shared index values. Values on either Series that did not have a shared index will produce a NULL/NaN (not a number).

# %% [markdown]
# ## DATAFRAME

# %% [markdown]
# Inevitably, we want to be able to store, view and manipulate data that is multivariate, where for every index there are multiple fields or columns of data, often of varying data type.
#
# A DataFrame is a tabular data structure, encapsulating multiple series like columns in a spreadsheet. Data are stored internally as a 2-dimensional object, but the DataFrame allows us to represent and manipulate higher-dimensional data.

# %%
data=pd.DataFrame({'points':[632, 1638, 569, 115],
                   'team':['India','China','Pakistan','Bhutan'],
                   'captain':['Suresh','Ramesh','Kamlesh','Dharmesh']
                  })
print(data)
# Out:
#     captain  points      team
# 0    Suresh     632     India
# 1    Ramesh    1638     China
# 2   Kamlesh     569  Pakistan
# 3  Dharmesh     115    Bhutan

# %% [markdown]
# Notice the DataFrame is sorted by column name. We can change the order by indexing them in the order we desire:

# %%
data[['team','captain','points']]
# Out:
#        team   captain  points
# 0     India    Suresh     632
# 1     China    Ramesh    1638
# 2  Pakistan   Kamlesh     569
# 3    Bhutan  Dharmesh     115

# %%
#A DataFrame has a second index, representing the columns:
data.columns
# Out:
# Index(['captain', 'points', 'team'], dtype='object')

# %%
#The dtypes attribute reveals the data type for each column in our DataFrame.
data.dtypes
# Out:
# captain    object
# points      int64
# team       object
# dtype: object

# %% [markdown]
# object refers to strings(letters and numbers)

# %%
#accessing columns
data['team']
#or
data.team
# Out:
# 0       India
# 1       China
# 2    Pakistan
# 3      Bhutan
# Name: team, dtype: object

# %%
print(type(data.points))
data[['points']]
#prints a column
# Out:
# <class 'pandas.core.series.Series'>
#    points
# 0     632
# 1    1638
# 2     569
# 3     115

# %%
#accesing rows in a dataFrame
data.loc[3]
#see the square brackets
data.head()
data.tail(3)
data.shape
# Out:
# (4, 3)

# %%
#An alternative way of initializing a DataFrame is with a list of dicts:
data = pd.DataFrame([{'patient': 1, 'phylum': 'Firmicutes', 'value': 632},
                    {'patient': 1, 'phylum': 'Proteobacteria', 'value': 1638},
                    {'patient': 1, 'phylum': 'Actinobacteria', 'value': 569},
                    {'patient': 1, 'phylum': 'Bacteroidetes', 'value': 115},
                    {'patient': 2, 'phylum': 'Firmicutes', 'value': 433},
                    {'patient': 2, 'phylum': 'Proteobacteria', 'value': 1130},
                    {'patient': 2, 'phylum': 'Actinobacteria', 'value': 754},
                    {'patient': 2, 'phylum': 'Bacteroidetes', 'value': 555}])
data
# Out:
#    patient          phylum  value
# 0        1      Firmicutes    632
# 1        1  Proteobacteria   1638
# 2        1  Actinobacteria    569
# 3        1   Bacteroidetes    115
# 4        2      Firmicutes    433
# 5        2  Proteobacteria   1130
# 6        2  Actinobacteria    754
# 7        2   Bacteroidetes    555

# %%
#this returns a view of the data frame
vals = data.value
vals
vals[5] = 0
vals
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0     632
# 1    1638
# 2     569
# 3     115
# 4     433
# 5       0
# 6     754
# 7     555
# Name: value, dtype: int64

# %%
vals = data.value.copy()
vals[5] = 1000
data
# Out:
#    patient          phylum  value
# 0        1      Firmicutes    632
# 1        1  Proteobacteria   1638
# 2        1  Actinobacteria    569
# 3        1   Bacteroidetes    115
# 4        2      Firmicutes    433
# 5        2  Proteobacteria      0
# 6        2  Actinobacteria    754
# 7        2   Bacteroidetes    555

# %%
data['year'] = 2013
data
# Out:
#    patient          phylum  value  year
# 0        1      Firmicutes    632  2013
# 1        1  Proteobacteria   1638  2013
# 2        1  Actinobacteria    569  2013
# 3        1   Bacteroidetes    115  2013
# 4        2      Firmicutes    433  2013
# 5        2  Proteobacteria      0  2013
# 6        2  Actinobacteria    754  2013
# 7        2   Bacteroidetes    555  2013

# %%
#From the data table above, create an index to return all rows for which the 
#Phylum name ends in "bacteria" and the value is greater than 1000.
data[(data.phylum.str.endswith('bacteria')) & (data.value>1000)]
# Out:
#    patient          phylum  value  year
# 1        1  Proteobacteria   1638  2013

# %% [markdown]
# Specifying a Series as a new columns cause its values to be added according to the DataFrame's index:

# %%
treatment = pd.Series([0]*4+[1]*2)#INDEX
treatment
data['treatment'] = treatment
data
# Out:
#    patient          phylum  value  year  treatment
# 0        1      Firmicutes    632  2013        0.0
# 1        1  Proteobacteria   1638  2013        0.0
# 2        1  Actinobacteria    569  2013        0.0
# 3        1   Bacteroidetes    115  2013        0.0
# 4        2      Firmicutes    433  2013        1.0
# 5        2  Proteobacteria      0  2013        1.0
# 6        2  Actinobacteria    754  2013        NaN
# 7        2   Bacteroidetes    555  2013        NaN

# %% [markdown]
# Other Python data structures (ones without an index) need to be the same length as the DataFrame:

# %%
data['month'] = ['Jan']*len(data)
data
# Out:
#    patient          phylum  value  year  treatment month
# 0        1      Firmicutes    632  2013        0.0   Jan
# 1        1  Proteobacteria   1638  2013        0.0   Jan
# 2        1  Actinobacteria    569  2013        0.0   Jan
# 3        1   Bacteroidetes    115  2013        0.0   Jan
# 4        2      Firmicutes    433  2013        1.0   Jan
# 5        2  Proteobacteria      0  2013        1.0   Jan
# 6        2  Actinobacteria    754  2013        NaN   Jan
# 7        2   Bacteroidetes    555  2013        NaN   Jan

# %%
data.drop('month',axis=1)
# Out:
#    patient          phylum  value  year  treatment
# 0        1      Firmicutes    632  2013        0.0
# 1        1  Proteobacteria   1638  2013        0.0
# 2        1  Actinobacteria    569  2013        0.0
# 3        1   Bacteroidetes    115  2013        0.0
# 4        2      Firmicutes    433  2013        1.0
# 5        2  Proteobacteria      0  2013        1.0
# 6        2  Actinobacteria    754  2013        NaN
# 7        2   Bacteroidetes    555  2013        NaN

# %%
#gives all the row as a ndarray
print(type(data.values))
data.values
# Out:
# <class 'numpy.ndarray'>
# array([[1, 'Firmicutes', 632, 2013, 0.0, 'Jan'],
#        [1, 'Proteobacteria', 1638, 2013, 0.0, 'Jan'],
#        [1, 'Actinobacteria', 569, 2013, 0.0, 'Jan'],
#        [1, 'Bacteroidetes', 115, 2013, 0.0, 'Jan'],
#        [2, 'Firmicutes', 433, 2013, 1.0, 'Jan'],
#        [2, 'Proteobacteria', 0, 2013, 1.0, 'Jan'],
#        [2, 'Actinobacteria', 754, 2013, nan, 'Jan'],
#        [2, 'Bacteroidetes', 555, 2013, nan, 'Jan']], dtype=object)

# %%
#index objects are immutable
data.index[0] = 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-2b76ffa08ea5> in <module>()
#       1 #index objects are immutable
# ----> 2 data.index[0] = 15
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    1668
#    1669     def __setitem__(self, key, value):
# -> 1670         raise TypeError("Index does not support mutable operations")
#    1671
#    1672     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
#getting summary of large dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
# patient      8 non-null int64
# phylum       8 non-null object
# value        8 non-null int64
# year         8 non-null int64
# treatment    6 non-null float64
# month        8 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 464.0+ bytes

# %% [markdown]
# ## Importing Data<br>CSV means Comma Separated Values

# %%
#you can get this from https://www.kaggle.com/egrinstein/20-years-of-games
#contains reviews about witcher 3
import pandas as pd
reviews=pd.read_csv("ign.csv")
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %% [markdown]
# Notice that read_csv automatically considered the first row in the file to be a header row.
# <br>
# We can override default behavior by customizing some the arguments, like header, names or index_col.
# <br>
# pd.read_csv("ign.csv", header=None).head()

# %%
reviews=pd.read_table("ign.csv", sep=',')
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %% [markdown]
# The sep argument can be customized as needed to accomodate arbitrary separators. For example, we can use a regular expression to define a variable amount of whitespace, which is unfortunately very common in some data formats:
#
# sep='\s+'

# %% [markdown]
# For a more useful index, we can specify the first two columns, which together provide a unique index to the data.

# %%
reviews.info()
#hierarchical Indexing
reviews=pd.read_csv("ign.csv",index_col=['Unnamed: 0','score_phrase'])
reviews.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18625 entries, 0 to 18624
# Data columns (total 11 columns):
# Unnamed: 0        18625 non-null int64
# score_phrase      18625 non-null object
# title             18625 non-null object
# url               18625 non-null object
# platform          18625 non-null object
# score             18625 non-null float64
# genre             18589 non-null object
# editors_choice    18625 non-null object
# release_year      18625 non-null int64
# release_month     18625 non-null int64
# release_day       18625 non-null int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.6+ MB
#                                                             title  \
#   score_phrase
# 0 Amazing                                 LittleBigPlanet PS Vita
# 1 Amazing       LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2 Great                                      Splice: Tree of Life
# 3 Great                                                    NHL 13
# 4 Great                                                    NHL 13
#
#                                                               url  \
#   score_phrase
# 0 Amazing                  /games/littlebigplanet-vita/vita-98907
# 1 Amazing       /games/littlebigplanet-ps-vita-marvel-super-he...
# 2 Great                                 /games/splice/ipad-141070
# 3 Great                             /games/nhl-13/xbox-360-128182
# 4 Great                                  /games/nhl-13/ps3-128181
#
#                         platform  score       genre editors_choice  \
#   score_phrase
# 0 Amazing       PlayStation Vita    9.0  Platformer              Y
# 1 Amazing       PlayStation Vita    9.0  Platformer              Y
# 2 Great                     iPad    8.5      Puzzle              N
# 3 Great                 Xbox 360    8.5      Sports              N
# 4 Great            PlayStation 3    8.5      Sports              N
#
#                 release_year  release_month  release_day
#   score_phrase
# 0 Amazing               2012              9           12
# 1 Amazing               2012              9           12
# 2 Great                 2012              9           12
# 3 Great                 2012              9           11
# 4 Great                 2012              9           11

# %% [markdown]
# If we have sections of data that we do not wish to import (for example, known bad data), we can populate the skiprows argument:

# %%
pd.read_csv("ign.csv",skiprows=[0]).head()
# Out:
#    0  Amazing                            LittleBigPlanet PS Vita  \
# 0  1  Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 1  2    Great                               Splice: Tree of Life
# 2  3    Great                                             NHL 13
# 3  4    Great                                             NHL 13
# 4  5     Good                          Total War Battles: Shogun
#
#               /games/littlebigplanet-vita/vita-98907  PlayStation Vita  9.0  \
# 0  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita  9.0
# 1                          /games/splice/ipad-141070              iPad  8.5
# 2                      /games/nhl-13/xbox-360-128182          Xbox 360  8.5
# 3                           /games/nhl-13/ps3-128181     PlayStation 3  8.5
# 4         /games/total-war-battles-shogun/mac-142565         Macintosh  7.0
#
#    Platformer  Y  2012  9  12
# 0  Platformer  Y  2012  9  12
# 1      Puzzle  N  2012  9  12
# 2      Sports  N  2012  9  11
# 3      Sports  N  2012  9  11
# 4    Strategy  N  2012  9  11

# %% [markdown]
# If we only want to import a small number of rows from, say, a very large data file we can use nrows:
# <br>
# Alternately, if we want to process our data in reasonable chunks, the chunksize argument will return an iterable object that can be employed in a data processing loop.

# %%
pd.read_csv("ign.csv",nrows=4)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11

# %%
chunk_review=pd.read_csv("ign.csv",chunksize=14)
r=pd.Series({chunk.iloc[0].title:chunk.score for chunk in chunk_review})
r
# Out:
# 102 Dalmatians: Puppies to the Rescue            2898    6.0
# 2899    6.6
# 2900    5.8
# 2901    3....
# 1602 A.D.                                        2002     7.9
# 2003     6.0
# 2004     5.0
# 2005   ...
# 1701 A.D.                                        8456    8.2
# 8457    5.0
# 8458    7.8
# 8459    3....
# 18-Wheeler American Pro Trucker                  3696    5.0
# 3697    6.3
# 3698    7.9
# 3699    5....
# 1942                                             7714    4.5
# 7715    4.8
# 7716    6.8
# 7717    7....
# 24: Special Ops                                  12740    7.2
# 12741    7.9
# 12742    5.0
# 12743  ...
# 3 on 3 NHL Arcade                                12460    5.9
# 12461    8.0
# 12462    4.0
# 12463  ...
# 300                                              9072    8.0
# 9073    7.3
# 9074    7.8
# 9075    6....
# 3D Classics: Urban Champion                      16016    2.5
# 16017    6.0
# 16018    7.5
# 16019  ...
# 3D Hunting Trophy Whitetail Championship 2009    12782    7.9
# 12783    7.0
# 12784    8.0
# 12785  ...
# 3D Pixel Racing                                  15904    6.0
# 15905    5.0
# 15906    7.5
# 15907  ...
# 6 Shooter Showdown: Poker                        6706    7.8
# 6707    6.0
# 6708    6.5
# 6709    8....
# 7 Wonders                                        9254    4.9
# 9255    5.7
# 9256    6.5
# 9257    5....
# 80 Days                                          18046    9.0
# 18047    6.0
# 18048    6.0
# 18049  ...
# A Valley Without Wind                            16716    5.5
# 16717    7.0
# 16718    7.0
# 16719  ...
# ATV Quad Power Racing                            3990    5.5
# 3991    8.3
# 3992    9.2
# 3993    6....
# Absolute Minesweeper                             8064    7.0
# 8065    5.3
# 8066    5.7
# 8067    8....
# Ace Combat 2                                     630    9.0
# 631    7.0
# 632    5.0
# 633    8.0
# 63...
# Aces of WWI                                      5726    8.0
# 5727    8.6
# 5728    6.8
# 5729    8....
# Advent Rising                                    6832    7.8
# 6833    7.1
# 6834    4.5
# 6835    7....
# AeroWings                                        1498    8.0
# 1499    8.7
# 1500    7.6
# 1501    8....
# Afrika                                           13594    3.5
# 13595    4.5
# 13596    5.0
# 13597  ...
# Afro Samurai                                     12446    6.6
# 12447    7.9
# 12448    7.5
# 12449  ...
# Again                                            14476    4.5
# 14477    5.0
# 14478    6.0
# 14479  ...
# Air Zonk                                         9534    8.0
# 9535    5.0
# 9536    3.0
# 9537    6....
# AirForce Delta Storm                             3472    6.2
# 3473    7.3
# 3474    3.0
# 3475    4....
# Airborne Troops: Countdown to D-Day              6594    3.5
# 6595    7.2
# 6596    3.3
# 6597    7....
# Akuji The Heartless                              1078    8.0
# 1079    5.2
# 1080    3.7
# 1081    5....
# Alien Crush Returns                              11830    7.8
# 11831    7.0
# 11832    5.3
# 11833  ...
# Aliens vs. Predator: Extinction                  4998    6.1
# 4999    3.8
# 5000    6.5
# 5001    7....
#                                                                        ...
# X-Men Legends II: Rise of Apocalypse             7056    8.5
# 7057    8.0
# 7058    7.7
# 7059    8....
# X-Men Origins: Wolverine -- Uncaged Edition      12866    7.8
# 12867    7.5
# 12868    7.8
# 12869  ...
# X-Men: Children of the Atom                      756    3.5
# 757    3.5
# 758    7.9
# 759    7.8
# 76...
# X-Men: Mutant Wars                               2716    5.0
# 2717    5.0
# 2718    4.7
# 2719    6....
# X-Men: Next Dimension                            4298    7.0
# 4299    9.3
# 4300    8.5
# 4301    8....
# X-Men: Wolverine's Rage                          3164    7.0
# 3165    6.0
# 3166    5.0
# 3167    7....
# X: Beyond the Frontier                           2072    7.7
# 2073    8.2
# 2074    7.0
# 2075    8....
# XCOM: Enemy Within -- Commander Edition          17388    9.0
# 17389    8.0
# 17390    8.0
# 17391  ...
# Xenophobe                                        1400     8.0
# 1401     5.0
# 1402     7.0
# 1403   ...
# Xiaolin Showdown                                 8722    6.0
# 8723    5.0
# 8724    8.0
# 8725    6....
# Y2K [2000]                                       2114    5.7
# 2115    5.0
# 2116    7.0
# 2117    5....
# Yahoo! Pyramids                                  6650    8.5
# 6651    8.8
# 6652    8.4
# 6653    8....
# Yakuza                                           8204    8.2
# 8205    6.5
# 8206    8.0
# 8207    3....
# Yakuza 4                                         15554    6.5
# 15555    9.0
# 15556    8.0
# 15557  ...
# Yard Sale Hidden Treasures: Sunnyville           14714    7.0
# 14715    8.9
# 14716    8.9
# 14717  ...
# You Don't Know Jack                              15372    6.0
# 15373    8.5
# 15374    6.5
# 15375  ...
# Your Doodles Are Bugged                          15694    7.5
# 15695    7.5
# 15696    8.0
# 15697  ...
# Zapper: One Wicked Cricket                       4788    5.5
# 4789    6.2
# 4790    5.5
# 4791    9....
# Zathura: A Space Adventure                       7392    3.4
# 7393    3.4
# 7394    7.8
# 7395    6....
# Zaxxon Motherbase 2000                           12166    4.0
# 12167    7.0
# 12168    9.3
# 12169  ...
# Zelda II: The Adventure of Link                  9422    8.5
# 9423    7.4
# 9424    5.5
# 9425    6....
# Zen Bound 2                                      15134     7.5
# 15135    10.0
# 15136     5.5
# 1513...
# Zen Pinball: Rollercoaster                       11396    7.0
# 11397    2.5
# 11398    3.0
# 11399  ...
# Zenonia 2: The Lost Memories                     14308    8.0
# 14309    7.0
# 14310    5.0
# 14311  ...
# Zoids Assault                                    11438    4.8
# 11439    6.5
# 11440    6.5
# 11441  ...
# Zoo Tycoon 2: Endangered Species                 7532    6.5
# 7533    7.4
# 7534    6.3
# 7535    9....
# Zuma                                             12558    8.0
# 12559    8.4
# 12560    5.5
# 12561  ...
# c-12: Final Resistance                           4074    6.8
# 4075    8.0
# 4076    7.2
# 4077    8....
# flOw                                             8974     7.6
# 8975     4.3
# 8976     7.2
# 8977   ...
# iBomber                                          13034    7.5
# 13035    8.4
# 13036    8.0
# 13037  ...
# Length: 1288, dtype: object

# %%
pd.isnull(reviews).head()
# Out:
#                 title    url  platform  score  genre  editors_choice  \
#   score_phrase
# 0 Amazing       False  False     False  False  False           False
# 1 Amazing       False  False     False  False  False           False
# 2 Great         False  False     False  False  False           False
# 3 Great         False  False     False  False  False           False
# 4 Great         False  False     False  False  False           False
#
#                 release_year  release_month  release_day
#   score_phrase
# 0 Amazing              False          False        False
# 1 Amazing              False          False        False
# 2 Great                False          False        False
# 3 Great                False          False        False
# 4 Great                False          False        False

# %%
#importing from microsoft excel
excel=pd.rea_excel("File Name")

# %% [markdown]
# # Pandas Fundamental

# %%
#Football International Friendlies data
results=pd.read_csv("results.csv")
results.tail()
# Out:
#              date home_team    away_team  home_score  away_score tournament  \
# 39003  2018-06-04     Italy  Netherlands           1           1   Friendly
# 39004  2018-06-04    Serbia        Chile           0           1   Friendly
# 39005  2018-06-04  Slovakia      Morocco           1           2   Friendly
# 39006  2018-06-04   Armenia      Moldova           0           0   Friendly
# 39007  2018-06-04     India        Kenya           3           0   Friendly
#
#           city      country  neutral
# 39003    Turin        Italy    False
# 39004     Graz      Austria     True
# 39005   Geneva  Switzerland     True
# 39006  Kematen      Austria     True
# 39007   Mumbai        India    False

# %%
team_unique=results.date.astype(str)+results.home_team+results.away_team
result_copy=results.copy()
result_copy.index=team_unique
result_copy.head()
# Out:
#                                  date home_team away_team  home_score  \
# 1872-11-30ScotlandEngland  1872-11-30  Scotland   England           0
# 1873-03-08EnglandScotland  1873-03-08   England  Scotland           4
# 1874-03-07ScotlandEngland  1874-03-07  Scotland   England           2
# 1875-03-06EnglandScotland  1875-03-06   England  Scotland           2
# 1876-03-04ScotlandEngland  1876-03-04  Scotland   England           3
#
#                            away_score tournament     city   country  neutral
# 1872-11-30ScotlandEngland           0   Friendly  Glasgow  Scotland    False
# 1873-03-08EnglandScotland           2   Friendly   London   England    False
# 1874-03-07ScotlandEngland           1   Friendly  Glasgow  Scotland    False
# 1875-03-06EnglandScotland           2   Friendly   London   England    False
# 1876-03-04ScotlandEngland           0   Friendly  Glasgow  Scotland    False

# %%
result_copy.index.is_unique
# Out:
# False

# %% [markdown]
# ### Manipulating indices

# %% [markdown]
# Reindexing allows users to manipulate the data labels in a DataFrame. It forces a DataFrame to conform to the new index, and optionally, fill in missing data if requested.
# <br>
# A simple use of reindex is to alter the order of the rows:

# %%
results.reindex(results.index[::-1]).head()
# Out:
#              date home_team    away_team  home_score  away_score tournament  \
# 39007  2018-06-04     India        Kenya           3           0   Friendly
# 39006  2018-06-04   Armenia      Moldova           0           0   Friendly
# 39005  2018-06-04  Slovakia      Morocco           1           2   Friendly
# 39004  2018-06-04    Serbia        Chile           0           1   Friendly
# 39003  2018-06-04     Italy  Netherlands           1           1   Friendly
#
#           city      country  neutral
# 39007   Mumbai        India    False
# 39006  Kematen      Austria     True
# 39005   Geneva  Switzerland     True
# 39004     Graz      Austria     True
# 39003    Turin        Italy    False

# %%
id_range=range(results.index.values.min(),results.index.values.max())
results.reindex(id_range).head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %% [markdown]
# We could specify and index that is a sequence from the first to the last id numbers in the database, and Pandas would fill in the missing data with NaN values:
# Keep in mind that reindex does not work if we pass a non-unique index series.

# %% [markdown]
# Indexing and Selection

# %%
# Getting Unique Values Across Multiple Columns in a Pandas Dataframe
teams=pd.unique(results[['home_team','away_team']].values.ravel())
teams
# Out:
# array(['Scotland', 'England', 'Wales', 'Northern Ireland', 'USA',
#        'Canada', 'Uruguay', 'Argentina', 'Austria', 'Hungary',
#        'Czechoslovakia', 'Belgium', 'France', 'Switzerland',
#        'Netherlands', 'Germany', 'Sweden', 'Norway', 'Italy', 'Chile',
#        'Finland', 'Luxembourg', 'Russia', 'Denmark', 'Brazil', 'Japan',
#        'Philippines', 'Paraguay', 'Estonia', 'Costa Rica', 'El Salvador',
#        'Guatemala', 'Yugoslavia', 'Poland', 'Spain', 'Portugal',
#        'Romania', 'New Zealand', 'Australia', 'Latvia', 'Mexico', 'China',
#        'Lithuania', 'Turkey', 'Aruba', 'Curaçao', 'Bulgaria', 'Egypt',
#        'South Africa', 'Haiti', 'Jamaica', 'Ireland', 'Kenya', 'Uganda',
#        'Bolivia', 'Peru', 'Honduras', 'Guyana', 'Trinidad and Tobago',
#        'Belarus', 'Ukraine', 'Barbados', 'Nicaragua', 'Greece',
#        'Martinique', 'Dominica', 'Cuba', 'Guadeloupe', 'Israel',
#        'Indonesia', 'Suriname', 'French Guyana', 'St. Lucia', 'Ecuador',
#        'Colombia', 'Venezuela', 'St. Kitts and Nevis', 'Grenada', 'India',
#        'Panama', 'Slovakia', 'Manchukuo', 'Croatia', 'Lebanon',
#        'Puerto Rico', 'Afghanistan', 'Iran', 'Mongolia', 'Tanzania',
#        'Zimbabwe', 'Zambia', 'Iceland', 'Albania', 'Montenegro',
#        'Madagascar', 'Mauritius', 'Réunion', 'Zanzibar', 'Djibouti',
#        'Ethiopia', 'Congo DR', 'Korea Republic', 'Vietnam', 'Macau',
#        'Dominican Republic', 'Cyprus', 'Sierra Leone', 'Nigeria', 'Syria',
#        'Serbia', 'Taiwan', 'Ghana', 'New Caledonia', 'Vanuatu', 'Fiji',
#        'Burma', 'Pakistan', 'Sri Lanka', 'German DR', 'Tahiti', 'Gambia',
#        'Hong Kong', 'Singapore', 'Malaysia', 'Guinea-Bissau', 'Saarland',
#        'Burundi', 'Cambodia', 'Thailand', 'Vietnam Republic',
#        'Kyrgyzstan', 'Moldova', 'North Vietnam', 'Togo', 'Korea DPR',
#        'Sudan', 'Malta', 'Tunisia', 'Libya', 'Malawi', 'Morocco', 'Benin',
#        'Cape Verde', 'Cameroon', 'Central African Republic', 'Mali',
#        'Gabon', 'Burkina Faso', 'Ivory Coast', 'Congo', 'Iraq', 'Guinea',
#        'St. Vincent and the Grenadines', 'Senegal', 'Algeria', 'Kuwait',
#        'Jordan', 'Solomon Islands', 'Liberia', 'Somalia', 'Laos',
#        'Saudi Arabia', 'Chad', 'Bermuda', 'Niger', 'Bahrain', 'Palestine',
#        'Yemen', 'Papua New Guinea', 'Wallis Islands and Futuna',
#        'Mauritania', 'Western Australia', 'Swaziland', 'Botswana',
#        'Qatar', 'Lesotho', 'Bahamas', 'Brunei', 'Cook Islands',
#        'Yemen DPR', 'United Arab Emirates', 'Faroe Islands', 'Nepal',
#        'Antigua and Barbuda', 'Bangladesh', 'Seychelles', 'Oman',
#        'Equatorial Guinea', 'Mozambique', 'Angola',
#        'São Tomé and Príncipe', 'Rwanda', 'Northern Cyprus', 'Armenia',
#        'Georgia', 'Azerbaijan', 'Kazakhstan', 'Guam', 'Tonga', 'Kiribati',
#        'Tuvalu', 'Samoa', 'Greenland', 'Liechtenstein', 'Bhutan', 'Niue',
#        'American Samoa', 'Belize', 'Cayman Islands', 'Anguilla',
#        'British Virgin Islands', 'Palau', 'Sint Maarten', 'Namibia',
#        'St. Martin', 'San Marino', 'Montserrat', 'Slovenia',
#        'Turkmenistan', 'Tajikistan', 'Uzbekistan', 'Eritrea',
#        'Czech Republic', 'Guernsey', 'Jersey', 'Bosnia-Herzegovina',
#        'Macedonia', 'Maldives', 'Andorra', 'Virgin Islands',
#        'Northern Mariana Islands', 'Turks and Caicos Islands',
#        'Micronesia FS', 'Tibet', 'Monaco', 'Mayotte', 'Gibraltar',
#        'Vatican', 'East Timor', 'Kosovo', 'Comoros',
#        'St. Pierre & Miquelon', 'Bonaire', 'South Sudan'], dtype=object)

# %% [markdown]
# The DataFrame.index and DataFrame.columns are placed in the query namespace by default. If you want to refer to a variable in the current namespace, you can prefix the variable with @:

# %%
min_home_score =2

# %% [markdown]
# For a more concise (and readable) syntax, we can use the new query method to perform selection on a DataFrame. Instead of having to type the fully-specified column, we can simply pass a string that describes what to select.

# %%
results.query('home_score > @min_home_score')
# Out:
#              date                 home_team                 away_team  \
# 1      1873-03-08                   England                  Scotland
# 4      1876-03-04                  Scotland                   England
# 5      1876-03-25                  Scotland                     Wales
# 8      1878-03-02                  Scotland                   England
# 9      1878-03-23                  Scotland                     Wales
# 11     1879-04-05                   England                  Scotland
# 13     1880-03-13                  Scotland                   England
# 15     1880-03-27                  Scotland                     Wales
# 20     1882-02-25                     Wales          Northern Ireland
# 21     1882-03-11                  Scotland                   England
# 22     1882-03-13                     Wales                   England
# 23     1882-03-25                  Scotland                     Wales
# 24     1883-02-03                   England                     Wales
# 25     1883-02-24                   England          Northern Ireland
# 30     1884-02-09                     Wales          Northern Ireland
# 34     1884-03-29                  Scotland                     Wales
# 35     1885-02-28                   England          Northern Ireland
# 37     1885-03-14                  Scotland          Northern Ireland
# 42     1886-02-27                     Wales          Northern Ireland
# 47     1886-04-10                  Scotland                     Wales
# 48     1886-11-25                       USA                    Canada
# 49     1887-02-05                   England          Northern Ireland
# 50     1887-02-19                  Scotland          Northern Ireland
# 51     1887-02-26                   England                     Wales
# 52     1887-03-12          Northern Ireland                     Wales
# 55     1888-02-04                   England                     Wales
# 56     1888-03-03                     Wales          Northern Ireland
# 57     1888-03-10                  Scotland                     Wales
# 61     1888-09-19                  Scotland                    Canada
# 62     1889-02-23                   England                     Wales
# ...           ...                       ...                       ...
# 38809  2018-03-23                   Austria                  Slovenia
# 38823  2018-03-23                    Mexico                   Iceland
# 38825  2018-03-23                    Norway                 Australia
# 38833  2018-03-23                 Singapore                  Maldives
# 38843  2018-03-24                   Georgia                 Lithuania
# 38851  2018-03-24                    Tahiti             New Caledonia
# 38852  2018-03-24                    Uganda     São Tomé and Príncipe
# 38856  2018-03-25             Faroe Islands             Liechtenstein
# 38861  2018-03-25                 Nicaragua                      Cuba
# 38867  2018-03-26                   Finland                     Malta
# 38875  2018-03-27                   Bahrain              Turkmenistan
# 38876  2018-03-27                   Belgium              Saudi Arabia
# 38879  2018-03-27  Central African Republic                     Kenya
# 38894  2018-03-27                  Maldives                    Bhutan
# 38902  2018-03-27                      Peru                   Iceland
# 38904  2018-03-27                    Poland            Korea Republic
# 38910  2018-03-27                     Spain                 Argentina
# 38911  2018-03-27               Switzerland                    Panama
# 38919  2018-04-01                  Malaysia                    Bhutan
# 38929  2018-05-20                    Jordan                    Cyprus
# 38934  2018-05-27                     Niger  Central African Republic
# 38937  2018-05-28                       USA                   Bolivia
# 38949  2018-05-29                 Argentina                     Haiti
# 38952  2018-05-29                Azerbaijan                Kyrgyzstan
# 38964  2018-05-31                   Romania                     Chile
# 38969  2018-06-01                    France                     Italy
# 38976  2018-06-01                  Botswana                 Mauritius
# 38978  2018-06-01                     India                    Taiwan
# 38998  2018-06-03                Costa Rica          Northern Ireland
# 39007  2018-06-04                     India                     Kenya
#
#        home_score  away_score                   tournament            city  \
# 1               4           2                     Friendly          London
# 4               3           0                     Friendly         Glasgow
# 5               4           0                     Friendly         Glasgow
# 8               7           2                     Friendly         Glasgow
# 9               9           0                     Friendly         Glasgow
# 11              5           4                     Friendly          London
# 13              5           4                     Friendly         Glasgow
# 15              5           1                     Friendly         Glasgow
# 20              7           1                     Friendly         Wrexham
# 21              5           1                     Friendly         Glasgow
# 22              5           3                     Friendly         Wrexham
# 23              5           0                     Friendly         Glasgow
# 24              5           0                     Friendly          London
# 25              7           0                     Friendly       Liverpool
# 30              6           0         British Championship         Wrexham
# 34              4           1         British Championship         Glasgow
# 35              4           0         British Championship      Manchester
# 37              8           2         British Championship         Glasgow
# 42              5           0         British Championship         Wrexham
# 47              4           1         British Championship         Glasgow
# 48              3           2                     Friendly          Newark
# 49              7           0         British Championship       Sheffield
# 50              4           1         British Championship         Glasgow
# 51              4           0         British Championship          London
# 52              4           1         British Championship         Belfast
# 55              5           1         British Championship           Crewe
# 56             11           0         British Championship         Wrexham
# 57              5           1         British Championship       Edinburgh
# 61              4           0                     Friendly         Glasgow
# 62              4           1         British Championship  Stoke-on-Trent
# ...           ...         ...                          ...             ...
# 38809           3           0                     Friendly      Klagenfurt
# 38823           3           0                     Friendly     Santa Clara
# 38825           4           1                     Friendly            Oslo
# 38833           3           2                     Friendly         Kallang
# 38843           4           0                     Friendly         Tbilisi
# 38851           4           3                     Friendly           Pirae
# 38852           3           1                     Friendly         Kampala
# 38856           3           0                     Friendly        Marbella
# 38861           3           3                     Friendly         Managua
# 38867           5           0                     Friendly           Belek
# 38875           4           0  AFC Asian Cup qualification           Riffa
# 38876           4           0                     Friendly        Brussels
# 38879           3           2                     Friendly       Marrakech
# 38894           7           0  AFC Asian Cup qualification            Malé
# 38902           3           1                     Friendly        Harrison
# 38904           3           2                     Friendly         Chorzów
# 38910           6           1                     Friendly          Madrid
# 38911           6           0                     Friendly         Lucerne
# 38919           7           0                     Friendly    Kuala Lumpur
# 38929           3           0                     Friendly           Amman
# 38934           3           3                     Friendly          Niamey
# 38937           3           0                     Friendly         Chester
# 38949           4           0                     Friendly    Buenos Aires
# 38952           3           0                     Friendly            Baku
# 38964           3           2                     Friendly            Graz
# 38969           3           1                     Friendly            Nice
# 38976           6           0                   COSAFA Cup       Polokwane
# 38978           5           0                     Friendly          Mumbai
# 38998           3           0                     Friendly        San José
# 39007           3           0                     Friendly          Mumbai
#
#             country  neutral
# 1           England    False
# 4          Scotland    False
# 5          Scotland    False
# 8          Scotland    False
# 9          Scotland    False
# 11          England    False
# 13         Scotland    False
# 15         Scotland    False
# 20            Wales    False
# 21         Scotland    False
# 22            Wales    False
# 23         Scotland    False
# 24          England    False
# 25          England    False
# 30            Wales    False
# 34         Scotland    False
# 35          England    False
# 37         Scotland    False
# 42            Wales    False
# 47         Scotland    False
# 48              USA    False
# 49          England    False
# 50         Scotland    False
# 51          England    False
# 52          Ireland    False
# 55          England    False
# 56            Wales    False
# 57         Scotland    False
# 61         Scotland    False
# 62          England    False
# ...             ...      ...
# 38809       Austria    False
# 38823           USA     True
# 38825        Norway    False
# 38833     Singapore    False
# 38843       Georgia    False
# 38851        Tahiti    False
# 38852        Uganda    False
# 38856         Spain     True
# 38861     Nicaragua    False
# 38867        Turkey     True
# 38875       Bahrain    False
# 38876       Belgium    False
# 38879       Morocco     True
# 38894      Maldives    False
# 38902           USA     True
# 38904        Poland    False
# 38910         Spain    False
# 38911   Switzerland    False
# 38919      Malaysia    False
# 38929        Jordan    False
# 38934         Niger    False
# 38937           USA    False
# 38949     Argentina    False
# 38952    Azerbaijan    False
# 38964       Austria     True
# 38969        France    False
# 38976  South Africa     True
# 38978         India    False
# 38998    Costa Rica    False
# 39007         India    False
#
# [9451 rows x 9 columns]

# %% [markdown]
# ### Operations

# %%
hs2017=results.loc[results.date>"2017-01-01",'date']
hs2018=results.loc[results.date>"2018-01-01",'date']
hstotal=hs2017+hs2018
hstotal
# Out:
# 37911                     NaN
# 37912                     NaN
# 37913                     NaN
# 37914                     NaN
# 37915                     NaN
# 37916                     NaN
# 37917                     NaN
# 37918                     NaN
# 37919                     NaN
# 37920                     NaN
# 37921                     NaN
# 37922                     NaN
# 37923                     NaN
# 37924                     NaN
# 37925                     NaN
# 37926                     NaN
# 37927                     NaN
# 37928                     NaN
# 37929                     NaN
# 37930                     NaN
# 37931                     NaN
# 37932                     NaN
# 37933                     NaN
# 37934                     NaN
# 37935                     NaN
# 37936                     NaN
# 37937                     NaN
# 37938                     NaN
# 37939                     NaN
# 37940                     NaN
#                  ...
# 38978    2018-06-012018-06-01
# 38979    2018-06-022018-06-02
# 38980    2018-06-022018-06-02
# 38981    2018-06-022018-06-02
# 38982    2018-06-022018-06-02
# 38983    2018-06-022018-06-02
# 38984    2018-06-022018-06-02
# 38985    2018-06-022018-06-02
# 38986    2018-06-022018-06-02
# 38987    2018-06-022018-06-02
# 38988    2018-06-022018-06-02
# 38989    2018-06-022018-06-02
# 38990    2018-06-022018-06-02
# 38991    2018-06-022018-06-02
# 38992    2018-06-022018-06-02
# 38993    2018-06-022018-06-02
# 38994    2018-06-032018-06-03
# 38995    2018-06-032018-06-03
# 38996    2018-06-032018-06-03
# 38997    2018-06-032018-06-03
# 38998    2018-06-032018-06-03
# 38999    2018-06-032018-06-03
# 39000    2018-06-032018-06-03
# 39001    2018-06-032018-06-03
# 39002    2018-06-032018-06-03
# 39003    2018-06-042018-06-04
# 39004    2018-06-042018-06-04
# 39005    2018-06-042018-06-04
# 39006    2018-06-042018-06-04
# 39007    2018-06-042018-06-04
# Name: date, Length: 1097, dtype: object

# %% [markdown]
# Pandas' data alignment places NaN values for labels that do not overlap in the two Series

# %%
hstotal[hstotal.notnull()]
# Out:
# 38767    2018-01-022018-01-02
# 38768    2018-01-022018-01-02
# 38769    2018-01-052018-01-05
# 38770    2018-01-072018-01-07
# 38771    2018-01-112018-01-11
# 38772    2018-01-112018-01-11
# 38773    2018-01-112018-01-11
# 38774    2018-01-142018-01-14
# 38775    2018-01-272018-01-27
# 38776    2018-01-282018-01-28
# 38777    2018-01-302018-01-30
# 38778    2018-01-302018-01-30
# 38779    2018-01-312018-01-31
# 38780    2018-02-032018-02-03
# 38781    2018-02-262018-02-26
# 38782    2018-02-282018-02-28
# 38783    2018-03-172018-03-17
# 38784    2018-03-212018-03-21
# 38785    2018-03-212018-03-21
# 38786    2018-03-212018-03-21
# 38787    2018-03-212018-03-21
# 38788    2018-03-212018-03-21
# 38789    2018-03-212018-03-21
# 38790    2018-03-212018-03-21
# 38791    2018-03-212018-03-21
# 38792    2018-03-212018-03-21
# 38793    2018-03-222018-03-22
# 38794    2018-03-222018-03-22
# 38795    2018-03-222018-03-22
# 38796    2018-03-222018-03-22
#                  ...
# 38978    2018-06-012018-06-01
# 38979    2018-06-022018-06-02
# 38980    2018-06-022018-06-02
# 38981    2018-06-022018-06-02
# 38982    2018-06-022018-06-02
# 38983    2018-06-022018-06-02
# 38984    2018-06-022018-06-02
# 38985    2018-06-022018-06-02
# 38986    2018-06-022018-06-02
# 38987    2018-06-022018-06-02
# 38988    2018-06-022018-06-02
# 38989    2018-06-022018-06-02
# 38990    2018-06-022018-06-02
# 38991    2018-06-022018-06-02
# 38992    2018-06-022018-06-02
# 38993    2018-06-022018-06-02
# 38994    2018-06-032018-06-03
# 38995    2018-06-032018-06-03
# 38996    2018-06-032018-06-03
# 38997    2018-06-032018-06-03
# 38998    2018-06-032018-06-03
# 38999    2018-06-032018-06-03
# 39000    2018-06-032018-06-03
# 39001    2018-06-032018-06-03
# 39002    2018-06-032018-06-03
# 39003    2018-06-042018-06-04
# 39004    2018-06-042018-06-04
# 39005    2018-06-042018-06-04
# 39006    2018-06-042018-06-04
# 39007    2018-06-042018-06-04
# Name: date, Length: 241, dtype: object

# %%
# We can also apply functions to each column or row of a DataFrame
import numpy as np
result=results.home_score
result.apply(np.median)
# Out:
# 0        0.0
# 1        4.0
# 2        2.0
# 3        2.0
# 4        3.0
# 5        4.0
# 6        1.0
# 7        0.0
# 8        7.0
# 9        9.0
# 10       2.0
# 11       5.0
# 12       0.0
# 13       5.0
# 14       2.0
# 15       5.0
# 16       0.0
# 17       1.0
# 18       1.0
# 19       0.0
# 20       7.0
# 21       5.0
# 22       5.0
# 23       5.0
# 24       5.0
# 25       7.0
# 26       2.0
# 27       0.0
# 28       1.0
# 29       0.0
#         ...
# 38978    5.0
# 38979    1.0
# 38980    0.0
# 38981    2.0
# 38982    0.0
# 38983    1.0
# 38984    0.0
# 38985    2.0
# 38986    0.0
# 38987    2.0
# 38988    2.0
# 38989    2.0
# 38990    0.0
# 38991    1.0
# 38992    1.0
# 38993    2.0
# 38994    1.0
# 38995    0.0
# 38996    1.0
# 38997    0.0
# 38998    3.0
# 38999    0.0
# 39000    0.0
# 39001    0.0
# 39002    1.0
# 39003    1.0
# 39004    0.0
# 39005    1.0
# 39006    0.0
# 39007    3.0
# Name: home_score, Length: 39008, dtype: float64

# %% [markdown]
# ### Sorting and Rannking

# %%
results.sort_index().head()
results.sort_index(ascending=False).head()
#sorting columns
results.sort_index(axis=1).head()
#sorting a Series by value
result.sort_values()
results[['home_score','away_score','home_team']].sort_values(ascending=[False,True],by=['home_score','away_score']).head()
# Out:
#        home_score  away_score  home_team
# 23569          31           0  Australia
# 10860          24           0       Fiji
# 23566          22           0  Australia
# 22344          20           0     Kuwait
# 22257          19           0      China

# %% [markdown]
# Ranking does not re-arrange data, but instead returns an index that ranks each value relative to others in the Series.

# %%
results.home_score.rank(ascending=False)
# Out:
# 0        34333.5
# 1         3678.5
# 2        13780.5
# 3        13780.5
# 4         7153.0
# 5         3678.5
# 6        23884.0
# 7        34333.5
# 8          600.5
# 9          207.0
# 10       13780.5
# 11        1939.5
# 12       34333.5
# 13        1939.5
# 14       13780.5
# 15        1939.5
# 16       34333.5
# 17       23884.0
# 18       23884.0
# 19       34333.5
# 20         600.5
# 21        1939.5
# 22        1939.5
# 23        1939.5
# 24        1939.5
# 25         600.5
# 26       13780.5
# 27       34333.5
# 28       23884.0
# 29       34333.5
#           ...
# 38978     1939.5
# 38979    23884.0
# 38980    34333.5
# 38981    13780.5
# 38982    34333.5
# 38983    23884.0
# 38984    34333.5
# 38985    13780.5
# 38986    34333.5
# 38987    13780.5
# 38988    13780.5
# 38989    13780.5
# 38990    34333.5
# 38991    23884.0
# 38992    23884.0
# 38993    13780.5
# 38994    23884.0
# 38995    34333.5
# 38996    23884.0
# 38997    34333.5
# 38998     7153.0
# 38999    34333.5
# 39000    34333.5
# 39001    34333.5
# 39002    23884.0
# 39003    23884.0
# 39004    34333.5
# 39005    23884.0
# 39006    34333.5
# 39007     7153.0
# Name: home_score, Length: 39008, dtype: float64

# %%
#hierarchical Indexing
result=results.set_index(['date','home_team','away_team'])
result.head()
# Out:
#                                 home_score  away_score tournament     city  \
# date       home_team away_team
# 1872-11-30 Scotland  England             0           0   Friendly  Glasgow
# 1873-03-08 England   Scotland            4           2   Friendly   London
# 1874-03-07 Scotland  England             2           1   Friendly  Glasgow
# 1875-03-06 England   Scotland            2           2   Friendly   London
# 1876-03-04 Scotland  England             3           0   Friendly  Glasgow
#
#                                  country  neutral
# date       home_team away_team
# 1872-11-30 Scotland  England    Scotland    False
# 1873-03-08 England   Scotland    England    False
# 1874-03-07 Scotland  England    Scotland    False
# 1875-03-06 England   Scotland    England    False
# 1876-03-04 Scotland  England    Scotland    False

# %% [markdown]
# This index is a MultiIndex object that consists of a sequence of tuples, the elements of which is some combination of the three columns used to create the index. Where there are multiple repeated values, Pandas does not print the repeats, making it easy to identify groups of values.

# %%
result.sum()
result.mean()
result.mean(skipna=False)
result.describe()
# Out:
#          home_score    away_score
# count  39008.000000  39008.000000
# mean       1.740130      1.180091
# std        1.730864      1.378856
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %% [markdown]
# #### Writing data to a file

# %%
results.to_csv("mb.csv")
# An efficient way of storing data to disk is in binary format.
results.to_pickle("football_pickle")
pd.read_pickle("football_pickle")
# Out:
#              date         home_team         away_team  home_score  away_score  \
# 0      1872-11-30          Scotland           England           0           0
# 1      1873-03-08           England          Scotland           4           2
# 2      1874-03-07          Scotland           England           2           1
# 3      1875-03-06           England          Scotland           2           2
# 4      1876-03-04          Scotland           England           3           0
# 5      1876-03-25          Scotland             Wales           4           0
# 6      1877-03-03           England          Scotland           1           3
# 7      1877-03-05             Wales          Scotland           0           2
# 8      1878-03-02          Scotland           England           7           2
# 9      1878-03-23          Scotland             Wales           9           0
# 10     1879-01-18           England             Wales           2           1
# 11     1879-04-05           England          Scotland           5           4
# 12     1879-04-07             Wales          Scotland           0           3
# 13     1880-03-13          Scotland           England           5           4
# 14     1880-03-15             Wales           England           2           3
# 15     1880-03-27          Scotland             Wales           5           1
# 16     1881-02-26           England             Wales           0           1
# 17     1881-03-12           England          Scotland           1           6
# 18     1881-03-14             Wales          Scotland           1           5
# 19     1882-02-18  Northern Ireland           England           0          13
# 20     1882-02-25             Wales  Northern Ireland           7           1
# 21     1882-03-11          Scotland           England           5           1
# 22     1882-03-13             Wales           England           5           3
# 23     1882-03-25          Scotland             Wales           5           0
# 24     1883-02-03           England             Wales           5           0
# 25     1883-02-24           England  Northern Ireland           7           0
# 26     1883-03-10           England          Scotland           2           3
# 27     1883-03-12             Wales          Scotland           0           3
# 28     1883-03-17  Northern Ireland             Wales           1           1
# 29     1884-01-26  Northern Ireland          Scotland           0           5
# ...           ...               ...               ...         ...         ...
# 38978  2018-06-01             India            Taiwan           5           0
# 38979  2018-06-02       El Salvador          Honduras           1           0
# 38980  2018-06-02          Thailand             China           0           2
# 38981  2018-06-02           England           Nigeria           2           1
# 38982  2018-06-02        Montenegro          Slovenia           0           2
# 38983  2018-06-02            Mexico          Scotland           1           0
# 38984  2018-06-02            Sweden           Denmark           0           0
# 38985  2018-06-02           Ireland               USA           2           1
# 38986  2018-06-02           Belgium          Portugal           0           0
# 38987  2018-06-02           Austria           Germany           2           1
# 38988  2018-06-02             Niger            Uganda           2           1
# 38989  2018-06-02           Iceland            Norway           2           3
# 38990  2018-06-02            Zambia           Namibia           0           0
# 38991  2018-06-02           Lesotho         Swaziland           1           0
# 38992  2018-06-02            Latvia           Estonia           1           0
# 38993  2018-06-02             Kenya       New Zealand           2           1
# 38994  2018-06-03           Albania           Ukraine           1           4
# 38995  2018-06-03      Saudi Arabia              Peru           0           3
# 38996  2018-06-03             Spain       Switzerland           1           1
# 38997  2018-06-03           Croatia            Brazil           0           2
# 38998  2018-06-03        Costa Rica  Northern Ireland           3           0
# 38999  2018-06-03          Barbados            Belize           0           0
# 39000  2018-06-03           Andorra        Cape Verde           0           0
# 39001  2018-06-03      South Africa        Madagascar           0           0
# 39002  2018-06-03          Zimbabwe          Botswana           1           1
# 39003  2018-06-04             Italy       Netherlands           1           1
# 39004  2018-06-04            Serbia             Chile           0           1
# 39005  2018-06-04          Slovakia           Morocco           1           2
# 39006  2018-06-04           Armenia           Moldova           0           0
# 39007  2018-06-04             India             Kenya           3           0
#
#                  tournament             city       country  neutral
# 0                  Friendly          Glasgow      Scotland    False
# 1                  Friendly           London       England    False
# 2                  Friendly          Glasgow      Scotland    False
# 3                  Friendly           London       England    False
# 4                  Friendly          Glasgow      Scotland    False
# 5                  Friendly          Glasgow      Scotland    False
# 6                  Friendly           London       England    False
# 7                  Friendly          Wrexham         Wales    False
# 8                  Friendly          Glasgow      Scotland    False
# 9                  Friendly          Glasgow      Scotland    False
# 10                 Friendly           London       England    False
# 11                 Friendly           London       England    False
# 12                 Friendly          Wrexham         Wales    False
# 13                 Friendly          Glasgow      Scotland    False
# 14                 Friendly          Wrexham         Wales    False
# 15                 Friendly          Glasgow      Scotland    False
# 16                 Friendly        Blackburn       England    False
# 17                 Friendly           London       England    False
# 18                 Friendly          Wrexham         Wales    False
# 19                 Friendly          Belfast       Ireland    False
# 20                 Friendly          Wrexham         Wales    False
# 21                 Friendly          Glasgow      Scotland    False
# 22                 Friendly          Wrexham         Wales    False
# 23                 Friendly          Glasgow      Scotland    False
# 24                 Friendly           London       England    False
# 25                 Friendly        Liverpool       England    False
# 26                 Friendly        Sheffield       England    False
# 27                 Friendly          Wrexham         Wales    False
# 28                 Friendly          Belfast       Ireland    False
# 29     British Championship          Belfast       Ireland    False
# ...                     ...              ...           ...      ...
# 38978              Friendly           Mumbai         India    False
# 38979              Friendly          Houston           USA     True
# 38980              Friendly          Bangkok      Thailand    False
# 38981              Friendly           London       England    False
# 38982              Friendly        Podgorica    Montenegro    False
# 38983              Friendly      Mexico City        Mexico    False
# 38984              Friendly            Solna        Sweden    False
# 38985              Friendly           Dublin       Ireland    False
# 38986              Friendly         Brussels       Belgium    False
# 38987              Friendly       Klagenfurt       Austria    False
# 38988              Friendly           Niamey         Niger    False
# 38989              Friendly        Reykjavík       Iceland    False
# 38990            COSAFA Cup        Polokwane  South Africa     True
# 38991            COSAFA Cup        Polokwane  South Africa     True
# 38992            Baltic Cup             Riga        Latvia    False
# 38993              Friendly           Mumbai         India     True
# 38994              Friendly  Évian-les-Bains        France     True
# 38995              Friendly       St. Gallen   Switzerland     True
# 38996              Friendly        Vila-real         Spain    False
# 38997              Friendly        Liverpool       England     True
# 38998              Friendly         San José    Costa Rica    False
# 38999              Friendly       Bridgetown      Barbados    False
# 39000              Friendly           Almada      Portugal     True
# 39001            COSAFA Cup        Polokwane  South Africa    False
# 39002            COSAFA Cup        Polokwane  South Africa     True
# 39003              Friendly            Turin         Italy    False
# 39004              Friendly             Graz       Austria     True
# 39005              Friendly           Geneva   Switzerland     True
# 39006              Friendly          Kematen       Austria     True
# 39007              Friendly           Mumbai         India    False
#
# [39008 rows x 9 columns]

# %% [markdown]
# ## Data Wrangling

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook')

# %%
from datetime import datetime,date,time
print(datetime.now())
datetime.now().day
time(2,24)
# Out:
# 2018-06-07 15:38:04.783069
# datetime.time(2, 24)

# %%
segments=pd.read_csv("transit_segments.csv")
segments.head()
# Out:
#    mmsi               name  transit  segment  seg_length  avg_sog  min_sog  \
# 0     1        Us Govt Ves        1        1         5.1     13.2      9.2
# 1     1  Dredge Capt Frank        1        1        13.5     18.6     10.4
# 2     1      Us Gov Vessel        1        1         4.3     16.2     10.3
# 3     1      Us Gov Vessel        2        1         9.2     15.4     14.5
# 4     1  Dredge Capt Frank        2        1         9.2     15.4     14.6
#
#    max_sog  pdgt10        st_time       end_time
# 0     14.5    96.5  2/10/09 16:03  2/10/09 16:27
# 1     20.6   100.0   4/6/09 14:31   4/6/09 15:20
# 2     20.5   100.0   4/6/09 14:36   4/6/09 14:55
# 3     16.1   100.0  4/10/09 17:58  4/10/09 18:34
# 4     16.2   100.0  4/10/09 17:59  4/10/09 18:35

# %%
segments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262526 entries, 0 to 262525
# Data columns (total 11 columns):
# mmsi          262526 non-null int64
# name          262526 non-null object
# transit       262526 non-null int64
# segment       262526 non-null int64
# seg_length    262526 non-null float64
# avg_sog       262526 non-null float64
# min_sog       262526 non-null float64
# max_sog       262526 non-null float64
# pdgt10        262526 non-null float64
# st_time       262526 non-null object
# end_time      262526 non-null object
# dtypes: float64(5), int64(3), object(3)
# memory usage: 22.0+ MB

# %%
segments.seg_length.hist(bins=100)

# %%
segments.seg_length.apply(np.log).hist(bins=100)

# %%
segments.st_time.dtype
#converting date to datetime format
datetime.strptime(segments.st_time.loc[0],'%m/%d/%y %H:%M')
# Out:
# datetime.datetime(2009, 2, 10, 16, 3)

# %% [markdown]
# The dateutil package includes a parser that attempts to detect the format of the date strings, and convert them automatically.

# %%
from dateutil.parser import parse
parse(segments.st_time.iloc[0])
# Out:
# datetime.datetime(2009, 2, 10, 16, 3)

# %%
#converting all the datetime
#segments.st_time.apply(lambda d:datetime.strptime(d, '%m/%d/%y %H:%M'))
pd.to_datetime(segments.st_time[:])
# Out:
# 0        2009-02-10 16:03:00
# 1        2009-04-06 14:31:00
# 2        2009-04-06 14:36:00
# 3        2009-04-10 17:58:00
# 4        2009-04-10 17:59:00
# 5        2010-03-20 16:06:00
# 6        2010-03-20 18:05:00
# 7        2011-05-04 11:28:00
# 8        2010-06-05 11:23:00
# 9        2010-06-08 11:03:00
# 10       2010-06-14 17:07:00
# 11       2010-06-17 16:35:00
# 12       2010-07-11 11:51:00
# 13       2010-07-12 15:33:00
# 14       2010-07-20 19:23:00
# 15       2010-09-10 14:00:00
# 16       2011-03-14 16:13:00
# 17       2011-03-18 11:18:00
# 18       2011-04-25 16:37:00
# 19       2011-05-14 15:51:00
# 20       2011-05-19 12:34:00
# 21       2011-05-23 21:29:00
# 22       2011-05-25 11:46:00
# 23       2011-06-01 14:32:00
# 24       2011-06-07 14:43:00
# 25       2011-08-08 15:42:00
# 26       2011-09-06 20:59:00
# 27       2011-09-08 08:22:00
# 28       2011-09-12 14:56:00
# 29       2011-10-25 12:52:00
#                  ...
# 262496   2009-11-22 02:13:00
# 262497   2009-11-22 02:15:00
# 262498   2009-12-02 01:46:00
# 262499   2009-12-02 03:12:00
# 262500   2009-12-06 16:09:00
# 262501   2009-12-06 16:21:00
# 262502   2009-12-11 23:49:00
# 262503   2009-12-15 22:23:00
# 262504   2009-12-15 22:51:00
# 262505   2009-12-31 10:17:00
# 262506   2010-01-01 11:22:00
# 262507   2010-01-13 17:40:00
# 262508   2010-01-13 18:07:00
# 262509   2010-01-24 05:53:00
# 262510   2010-03-20 05:14:00
# 262511   2010-04-14 15:09:00
# 262512   2010-04-19 00:20:00
# 262513   2010-05-13 14:13:00
# 262514   2010-05-19 19:46:00
# 262515   2010-05-31 14:27:00
# 262516   2010-06-05 05:25:00
# 262517   2010-06-27 02:35:00
# 262518   2010-07-01 03:49:00
# 262519   2010-07-02 03:30:00
# 262520   2010-06-13 10:32:00
# 262521   2010-06-15 12:49:00
# 262522   2010-06-15 21:32:00
# 262523   2010-06-17 19:16:00
# 262524   2010-06-18 02:52:00
# 262525   2010-06-18 10:19:00
# Name: st_time, Length: 262526, dtype: datetime64[ns]

# %% [markdown]
# The read_* functions now have an optional parse_dates argument that try to convert any columns passed to it into datetime format upon import:

# %%
segments = pd.read_csv("transit_segments.csv", parse_dates=['st_time', 'end_time'])
#timeconsuming

# %%
segments.dtypes

# %% [markdown]
# Columns of the datetime type have an accessor to easily extract properties of the data type. This will return a Series, with the same row index as the DataFrame

# %%
segments.st_time.dt.month.head()

# %%
segments[segments.st_time.dt.month==2].head()

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
vessels = pd.read_csv("vessel_information.csv", index_col='mmsi')
vessels.head()
# Out:
#       num_names                                              names sov  \
# mmsi
# 1             8  Bil Holman Dredge/Dredge Capt Frank/Emo/Offsho...   Y
# 9             3                         000000009/Raven/Shearwater   N
# 21            1                                      Us Gov Vessel   Y
# 74            2                                  Mcfaul/Sarah Bell   N
# 103           3           Ron G/Us Navy Warship 103/Us Warship 103   Y
#
#          flag flag_type  num_loas                                    loa  \
# mmsi
# 1     Unknown   Unknown         7  42.0/48.0/57.0/90.0/138.0/154.0/156.0
# 9     Unknown   Unknown         2                              50.0/62.0
# 21    Unknown   Unknown         1                                  208.0
# 74    Unknown   Unknown         1                                  155.0
# 103   Unknown   Unknown         2                             26.0/155.0
#
#       max_loa  num_types                             type
# mmsi
# 1       156.0          4  Dredging/MilOps/Reserved/Towing
# 9        62.0          2                     Pleasure/Tug
# 21      208.0          1                          Unknown
# 74      155.0          1                          Unknown
# 103     155.0          2                   Tanker/Unknown

# %% [markdown]
# Merging and Joining DataFrame Objects

# %%
vessels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10771 entries, 1 to 999999999
# Data columns (total 10 columns):
# num_names    10771 non-null int64
# names        10771 non-null object
# sov          10771 non-null object
# flag         10771 non-null object
# flag_type    10771 non-null object
# num_loas     10771 non-null int64
# loa          10771 non-null object
# max_loa      10771 non-null float64
# num_types    10771 non-null int64
# type         10771 non-null object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 925.6+ KB

# %%
[v for v in vessels.type.unique() if v.find('/')==-1]
# Out:
# ['Unknown',
#  'Other',
#  'Tug',
#  'Towing',
#  'Pleasure',
#  'Cargo',
#  'WIG',
#  'Fishing',
#  'BigTow',
#  'MilOps',
#  'Tanker',
#  'Passenger',
#  'SAR',
#  'Sailing',
#  'Reserved',
#  'Law',
#  'Dredging',
#  'AntiPol',
#  'Pilot',
#  'HSC',
#  'Diving',
#  'Resol-18',
#  'Tender',
#  'Spare',
#  'Medical']

# %%
vessels.type.value_counts()
# Out:
# Cargo                                                                                5622
# Tanker                                                                               2440
# Pleasure                                                                              601
# Tug                                                                                   221
# Sailing                                                                               205
# Fishing                                                                               200
# Other                                                                                 178
# Passenger                                                                             150
# Towing                                                                                117
# Unknown                                                                               106
# MilOps                                                                                 82
# Cargo/Unknown                                                                          79
# Cargo/Other                                                                            63
# Cargo/Tanker                                                                           42
# Towing/Tug                                                                             30
# Tanker/Unknown                                                                         30
# BigTow                                                                                 29
# Dredging                                                                               24
# Fishing/Pleasure                                                                       24
# Reserved                                                                               20
# Cargo/Reserved                                                                         19
# BigTow/Towing                                                                          19
# Other/Tanker                                                                           16
# BigTow/Tug                                                                             15
# Tug/Unknown                                                                            15
# Cargo/MilOps                                                                           15
# HSC                                                                                    14
# SAR                                                                                    13
# Other/Pleasure                                                                         11
# BigTow/Towing/Tug                                                                      11
#                                                                                      ...
# MilOps/Tanker                                                                           1
# BigTow/Reserved/Towing/Tug                                                              1
# Sailing/Tanker                                                                          1
# MilOps/Reserved/Towing                                                                  1
# Fishing/Other/Towing                                                                    1
# Cargo/Sailing                                                                           1
# AntiPol/Other                                                                           1
# BigTow/Tanker/Towing/Tug                                                                1
# Sailing/Spare                                                                           1
# AntiPol/Fishing/Pleasure                                                                1
# BigTow/Sailing/Towing/Tug                                                               1
# AntiPol/BigTow/Fishing/Other/Passenger/Pilot/Pleasure/Resol-18/Sailing/Towing/Tug       1
# MilOps/Other/Towing                                                                     1
# Fishing/Tanker                                                                          1
# BigTow/Tanker/WIG                                                                       1
# Pilot/SAR/Unknown                                                                       1
# Tanker/Towing/Tug/Unknown/WIG                                                           1
# BigTow/Reserved/Towing/WIG                                                              1
# MilOps/Pleasure/Unknown                                                                 1
# Fishing/Towing/Tug/WIG                                                                  1
# MilOps/Other/Tanker                                                                     1
# Fishing/Pilot/Unknown                                                                   1
# Fishing/SAR/Tug                                                                         1
# BigTow/Fishing/Tug                                                                      1
# Other/Reserved/Tug                                                                      1
# Cargo/Fishing/MilOps/Other/Pleasure/Sailing/Spare/Tender/Towing                         1
# MilOps/Reserved/SAR/Tanker                                                              1
# BigTow/Resol-18/Towing                                                                  1
# Fishing/Towing/Tug                                                                      1
# AntiPol/MilOps/Unknown                                                                  1
# Name: type, Length: 206, dtype: int64

# %% [markdown]
# Combining tables according to the value of one or more keys that are used to identify rows much like an index

# %%
df1=pd.DataFrame(dict(id=range(4),age=np.random.randint(18,31,size=4)))
df2=pd.DataFrame(dict(id=list(range(3))+list(range(3)),score=np.random.random(size=6)))
print(df1)
df2
# Out:
#    age  id
# 0   18   0
# 1   27   1
# 2   29   2
# 3   22   3
#    id     score
# 0   0  0.662445
# 1   1  0.154939
# 2   2  0.918746
# 3   0  0.607628
# 4   1  0.308565
# 5   2  0.084825

# %%
pd.merge(df1,df2)
# Out:
#    age  id     score
# 0   18   0  0.662445
# 1   18   0  0.607628
# 2   27   1  0.154939
# 3   27   1  0.308565
# 4   29   2  0.918746
# 5   29   2  0.084825

# %% [markdown]
# Notice that without any information about which column to use as a key, Pandas did the right thing and used the id column in both tables. Unless specified otherwise, merge will used any common column names as keys for merging the tables.

# %% [markdown]
# Notice also that id=3 from df1 was omitted from the merged table. This is because, by default, merge performs an inner join on the tables, meaning that the merged table represents an intersection of the two tables.

# %% [markdown]
# how : {'left', 'right', 'outer', 'inner'}, default 'inner'
# <br>
#
# left: use only keys from left frame (SQL: left outer join)
# <br>
# right: use only keys from right frame (SQL: right outer join)
# <br>
# outer: use union of keys from both frames (SQL: full outer join)
# <br>
# inner: use intersection of keys from both frames (SQL: inner join)

# %%
pd.merge(df1, df2, how='outer')
# Out:
#    age  id     score
# 0   18   0  0.662445
# 1   18   0  0.607628
# 2   27   1  0.154939
# 3   27   1  0.308565
# 4   29   2  0.918746
# 5   29   2  0.084825
# 6   22   3       NaN

# %% [markdown]
# The outer join above yields the union of the two tables, so all rows are represented, with missing values inserted as appropriate. One can also perform right and left joins to include all rows of the right or left table (i.e. first or second argument to merge), but not necessarily the other.

# %% [markdown]
# ## Concatenation

# %%
np.concatenate([np.random.random(5), np.random.random(5)])
# Out:
# array([0.70043685, 0.66674175, 0.51207704, 0.234969  , 0.55904273,
#        0.29235015, 0.66438098, 0.3599379 , 0.41768643, 0.13056488])

# %%
pd.concat([df1,df2],axis=0,join='inner')

# %%
#Row wise concatenation
np.r_[np.random.random(5), np.random.random(5)]
# Out:
# array([0.11974038, 0.53828562, 0.47373625, 0.36580809, 0.01242733,
#        0.96611554, 0.5331864 , 0.13844634, 0.41681915, 0.69612816])

# %%
np.c_[np.random.random(5),np.random.random(5)]
# Out:
# array([[0.49973423, 0.28104362],
#        [0.52090108, 0.33484728],
#        [0.97136516, 0.40183446],
#        [0.00564331, 0.68287666],
#        [0.2212391 , 0.25271499]])

# %% [markdown]
# Notice that c_ and r_ are not really functions at all, since it is performing some sort of indexing operation, rather than being called. They are actually class instances,This operation is also called binding or stacking.

# %%
football=pd.read_csv("results.csv")
football.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
#Stack method rotates the data frame so that columns are represented in rows
stacked=football.stack()
stacked.head()
#To complement this, unstack pivots from rows back to columns.
stacked.unstack().head()
# Out:
#          date home_team away_team home_score away_score tournament     city  \
# 0  1872-11-30  Scotland   England          0          0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland          4          2   Friendly   London
# 2  1874-03-07  Scotland   England          2          1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland          2          2   Friendly   London
# 4  1876-03-04  Scotland   England          3          0   Friendly  Glasgow
#
#     country neutral
# 0  Scotland   False
# 1   England   False
# 2  Scotland   False
# 3   England   False
# 4  Scotland   False

# %%
foot=football.set_index(['date'])
foot.head()
# Out:
#            home_team away_team  home_score  away_score tournament     city  \
# date
# 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1873-03-08   England  Scotland           4           2   Friendly   London
# 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 1875-03-06   England  Scotland           2           2   Friendly   London
# 1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#              country  neutral
# date
# 1872-11-30  Scotland    False
# 1873-03-08   England    False
# 1874-03-07  Scotland    False
# 1875-03-06   England    False
# 1876-03-04  Scotland    False
